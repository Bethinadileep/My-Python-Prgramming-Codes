# %% [markdown]
# <a href="https://colab.research.google.com/github/Bethinadileep/My-Python-Prgramming-Codes/blob/main/PFTR_D2S3_Pandas_with_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Banner.png](data:image/png;base64,...)
#
#
# ---

# %% [markdown]
# # Data Analysis- using Pandas

# %% [markdown]
# [Iris Dataset](https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv)
#
# ![image.png](data:image/png;base64,...)
#
# The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.

# %% [markdown]
# To read a CSV file from internet👇

# %%
import pandas as pd 

data = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv") 
print(data)

# %% [markdown]
# To read a CSV file locally fom your system 👇

# %%
from google.colab import files
uploaded_file = files.upload()
# Out:
#      <input type="file" id="files-f0b8e602-95be-479e-8e6a-a014287e18ce" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f0b8e602-95be-479e-8e6a-a014287e18ce">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
data = pd.read_csv('iris.csv')
print(data)
# Out:
#                 Country Primary forest extent  ... % tree cover Tree cover loss
# 0                   NaN                 -2018  ...        -2018     (2001-2018)
# 1                Brazil          32,00,69,365  ...       55.40%     5,15,32,499
# 2              DR Congo          10,02,27,214  ...       81.20%     1,28,36,705
# 3             Indonesia           8,46,83,971  ...       75.60%     2,49,72,682
# 4                  Peru           6,73,18,459  ...       59.50%       27,38,812
# ..                  ...                   ...  ...          ...             ...
# 85          Timor-Leste                   350  ...       45.60%          25,936
# 86         Sint Maarten                   250  ...       21.90%              27
# 87               Gambia                   111  ...        0.30%             684
# 88  Antigua and Barbuda                    55  ...       44.40%             678
# 89                Aruba                     7  ...        0.10%               2
#
# ...

# %% [markdown]
# To 🖥 the first 5 rows👇

# %%
print(data.head())

# %% [markdown]
# To 🖥 the last 5 rows👇

# %%
print(data.tail())

# %% [markdown]
# To print 20 rows randomly👇

# %%
print(data.sample(20))

# %% [markdown]
# To disply all the columns of the dataset in a list form👇

# %%
print(data.columns)

# %% [markdown]
# To display the shape of the dataset
#
# 💁To print the total number of rows or entries and the total number of columns or features of that particular dataset.

# %%
print(data.shape)

# %% [markdown]
# Slicing the rows👇

# %%
# display rows from 21 to 30
print(data[21:31])

# %% [markdown]
# To display only specific columns👇

# %%
# mention the required columns, sepal_length and petal_length in a list format
my_columns = data[['sepal_length', 'petal_length']]

# display only first 5 rows
print(my_columns.head(10))

# %% [markdown]
# To display complete information about a particular row using index integer👇

# %%
# display all info in row 4 (row index starts from zero)
print(data.iloc[4])

# %% [markdown]
# To display records only with `sepal_length` as `5.1`👇

# %%
print(data.loc[data['sepal_length'] == 5.1])

# %% [markdown]
# To display records only with the following constraints
#
# `sepal_length` is `5.1` and `sepal_width` is `3.5`👇
#
# (Filter table based on multi column constraint)

# %%
print(data.loc[(data['sepal_length'] == 5.1) & (data['sepal_width'] == 3.5)])

# %% [markdown]
# Now, let us see the count of various species in the given dataset(Iris)👨‍🏫
#
# *value_counts() function, counts the number of times a particular instance or data has occurred.*

# %%
print(data['species'].value_counts())

# %% [markdown]
# ---
# Write the necessary code to find the occurence of petal_length.
#
# Expected Output
# ```
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.0     5
# 4.9     5
# 4.7     5
# 5.0     4
# 1.7     4
# 4.8     4
# 4.4     4
# 4.2     4
# 4.1     3
# 5.7     3
# 5.5     3
# 6.1     3
# 3.9     3
# 4.6     3
# 5.8     3
# 5.2     2
# 1.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 5.3     2
# 5.4     2
# 3.3     2
# 6.7     2
# 3.5     2
# 5.9     2
# 3.6     1
# 3.8     1
# 1.0     1
# 3.0     1
# 6.3     1
# 6.6     1
# 3.7     1
# 1.1     1
# 6.4     1
# 6.9     1
# ```

# %%
# code here

# %% [markdown]
# Write the necessary code to find the occurence of petal_length from row 1 to 19 .
#
# Expected Output
# ```
# 1.4    6
# 1.5    6
# 1.7    2
# 1.3    2
# 1.6    1
# 1.1    1
# 1.2    1
# ```

# %%
# slicing => 1 to 19
s = data[1:20]
print(s['petal_length'].value_counts())
# print((data[1:20])['petal_length'].value_counts())

# %% [markdown]
# ---
# To find sum, mean and mode of a particular column.

# %%
sum_data = data['petal_length'].sum()
mean_data = data['petal_length'].mean()
median_data = data['petal_length'].median()
print('Sum is', sum_data)
print('Mean is', mean_data)
print('Median is', median_data)

# %% [markdown]
# To find minimum and maximum from a column👇

# %%
# find the minimum value in column, petal_length
print('Min', data['petal_length'].min())

# find the maximum value in column, petal_length
print('Min', data['petal_length'].max())

# %% [markdown]
# Any missing data in my data set🤔

# %%
# if data is missing, it will display True else False
data.isnull()

# %% [markdown]
# # Solve Problem

# %%
import pandas as pd
from google.colab import files
my_file = files.upload()

# %%
# read child csv file

# display first 10 rows

# %% [markdown]
# #**Data Visualization**

# %% [markdown]
# `Matplotlib` is one of the most popular Python packages used for data visualization.

# %%
# Import Pyplot module from Matplotlib package
import matplotlib.pyplot as plt

# %% [markdown]
# `Scatter plots` are used to plot data points on horizontal and vertical axis in the attempt to show how much one variable is affected by another.

# %%
# x-axis => sepal_length
# y-axis => sepal_width
# title => Iris Dataset
data.plot.scatter(x='sepal_length', y='sepal_width', title='Iris Dataset')

# %% [markdown]
# Matplotlib has the concept of `subplots`: groups of smaller axes that can exist together within a single figure.
#
# * To compare different views of data side by side
# ```
# data.plot.hist(
#
#     subplots=True, # True to view every data side by side
#
#     layout=(2,2), # Grid size 2X2
#
#     figsize=(10, 10), # width and height in inches
#
#     bins=20  # number of intervals you want to divide all of your data into, such that it can be displayed as bars on a histogram
# )
# ```
#
#
# [Find optimum number of bins](https://academic.oup.com/biomet/article-abstract/66/3/605/232642)

# %%
data.plot.hist(subplots=True, layout=(2,3), figsize=(10, 10), bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3effef0dd0>,
# ...
#       dtype=object)

# %% [markdown]
# ---
# `Seaborn` is a Python data visualization library based on matplotlib.
# * It provides a high-level interface for drawing attractive and informative statistical graphics.
# * It uses Matplotlib underneath to plot graphs.

# %%
# Import the Seaborn module 
import seaborn as sns

# %% [markdown]
# To plot a graph with sepal_length vs sepal_width👇

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', data=data)

# %% [markdown]
# 💁To `group data points` on the basis of category - `species`

# %%
sns.scatterplot(x='sepal_length', y='sepal_width', hue='species', data=data)

# %% [markdown]
# To draw a graph with column, sepal_length dropped👇

# %%
sns.lineplot(data=data.drop(['sepal_length'], axis=1))

# %% [markdown]
# 😇A very simple way to find [correlation](https://www.investopedia.com/terms/c/correlation.asp) for dataset in your research work

# %%
sns.heatmap(data.corr(), annot=True)

# %% [markdown]
# To plot multiple pairwise bivariate distributions in a dataset👇

# %%
sns.pairplot(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-9f33636b51d6> in <module>()
# ----> 1 sns.pairplot(data)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1989     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1990                     hue_order=hue_order, palette=palette, corner=corner,
# -> 1991                     height=height, aspect=aspect, dropna=dropna, **grid_kws)
#    1992
# ...

# %% [markdown]
# Group it based on species👨‍🏫

# %%
sns.pairplot(data, hue='species')
